# %%
import numpy as np

def sigmoid(x):
    return 1/(1+np.exp(-x))


def numerical_derivative(x, t) :
    delta_x = 1e-4
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    
    while noe it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        
        x[idx] = tmp_val + delta_x
        fx1 = f(x)
        
        x[idx] = tmp_val - delta_x
        fx2 = f(x)
        
        grad[idx] = (fx1 - fx2) / (2*delta_x)
        x[idx] = tmp_val
        
        it.iternext()
        
    return grad

class LogicGate:
    
    def __init__(self, gate_name, xdata, tdata):
        
        delta = 1e-7
        
        self.name = gate_name
        
        self.__xdata = xdata.reshape(4, 2)
        self.__tdata = tdata.reshape(4, 1)
        
        self.__W = np.random.rand(2, 1)
        self.__b = np.random.rand(1)
        
        self.__learning_rate = 1e-2
        
        def loss_func(self):
            delta = 1e-7
            
            z = np.dot(self.__x, self.__W) + self.__b
            y = sigmoid(z)
            
            return -np.sum(self.__t * np.log(y + delta) + (1-self.__t) * np.log((1-y)+delta))
        
        def error_val(self):
            delta = 1e-7
            
            z = np.dot(self.__x, self.__W) + self.__b
            y = sigmoid(z)
            
            return -np.sum(self.__t*np.log(y + delta) + (1-self.__t)*np.log((1-y) + delta))
        
        
        def train(self):
            f = lambda x : numerical_derivative(self.__W, self.__b)
            learning_rate = 1e-4
            
            for step in range(8001):
                self.__W -= learning_rate * numerical_derivative(f, self.__W)
                self.__b -= learning_rate * numerical_derivative(f, self.__b)
                
                if (step%400 == 0):
                    print("step=", step, "error value=", self.error_val())
        
        def predict(self, input_data):
            z = np.dot(self.__x, self.__W) + self.__b
            y = sigmoid(z)
            
            if (y > 0.5):
                result = 1
            else :
                result = 0
            return y, result
        
        
        
        

input_data = np.array([0,0], [0, 1], [1, 0], [1, 1])

s1 = []
s2 = []

new_input_data = []
final_output = []

for index in range(len(input_data)):
    s1 = NAND
